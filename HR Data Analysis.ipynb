# %% [markdown]
# ![](HR-Analytics.webp)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Imran\HR Data Analysis Project\HR_Data.csv")

# %%
df
# Out:
#          Unnamed: 0 Employee_ID         Full_Name  Department  \
# 0                 0  EMP0000001     Joshua Nguyen          IT
# 1                 1  EMP0000002    Julie Williams   Marketing
# 2                 2  EMP0000003   Alyssa Martinez          HR
# 3                 3  EMP0000004   Nicholas Valdez          IT
# 4                 4  EMP0000005    Joel Hendricks  Operations
# ...             ...         ...               ...         ...
# 1999995     1999995  EMP1999996      Cody Russell  Operations
# 1999996     1999996  EMP1999997      Tracey Smith          IT
# 1999997     1999997  EMP1999998         Tracy Lee       Sales
# 1999998     1999998  EMP1999999  Michael Roberson          IT
# 1999999     1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title   Hire_Date  \
# 0                    Software Engineer  2011-08-10
# 1                       SEO Specialist  2018-03-02
# 2                           HR Manager  2023-03-20
# 3                    Software Engineer  2023-10-12
# 4                Logistics Coordinator  2024-12-09
# ...                                ...         ...
# 1999995          Logistics Coordinator  2010-08-31
# 1999996              Software Engineer  2021-05-07
# 1999997   Business Development Manager  2024-05-29
# 1999998              Software Engineer  2023-02-14
# 1999999  Talent Acquisition Specialist  2020-11-11
#
#                                         Location  Performance_Rating  \
# 0                             Isaacland, Denmark                   5
# 1                        Anthonyside, Costa Rica                   2
# 2               Port Christinaport, Saudi Arabia                   1
# 3        Port Shelbychester, Antigua and Barbuda                   1
# 4           Lake Kimberly, Palestinian Territory                   5
# ...                                          ...                 ...
# 1999995                         Casefurt, Serbia                   3
# 1999996                        Dannyport, Kuwait                   3
# 1999997                      Craighaven, Nigeria                   5
# 1999998                  Jonathanmouth, Djibouti                   4
# 1999999                    Morganchester, Canada                   1
#
#          Experience_Years    Status Work_Mode  Salary_INR
# 0                      14  Resigned   On-site     1585363
# 1                       7    Active   On-site      847686
# 2                       2    Active   On-site     1430084
# 3                       1    Active   On-site      990689
# 4                       0    Active   On-site      535082
# ...                   ...       ...       ...         ...
# 1999995                14    Active    Remote      657648
# 1999996                 4    Active   On-site     1030109
# 1999997                 1    Active    Remote     1313085
# 1999998                 2   Retired   On-site     1479727
# 1999999                 4    Active    Remote      993718
#
# [2000000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Employee_ID         object
#  2   Full_Name           object
#  3   Department          object
#  4   Job_Title           object
#  5   Hire_Date           object
#  6   Location            object
#  7   Performance_Rating  int64
#  8   Experience_Years    int64
#  9   Status              object
#  10  Work_Mode           object
#  11  Salary_INR          int64
# dtypes: int64(4), object(8)
# memory usage: 183.1+ MB

# %%
# Removing unnamed column from the dataframe
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title   Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer  2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist  2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
# Change the data type of Date column
df['Hire_Date'] = pd.to_datetime(df['Hire_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Employee_ID         object
#  1   Full_Name           object
#  2   Department          object
#  3   Job_Title           object
#  4   Hire_Date           datetime64[ns]
#  5   Location            object
#  6   Performance_Rating  int64
#  7   Experience_Years    int64
#  8   Status              object
#  9   Work_Mode           object
#  10  Salary_INR          int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 167.8+ MB

# %%
df['Performance_Rating'].unique()
# Out:
# array([5, 2, 1, 4, 3])

# %%
df['Performance_Rating'].value_counts()
# Out:
# Performance_Rating
# 4    400529
# 2    400174
# 3    399814
# 1    399756
# 5    399727
# Name: count, dtype: int64

# %%
df['Performance_Rating'].mean()
# Out:
# np.float64(3.0001485)

# %%
df['Experience_Years'].nunique()
# Out:
# 16

# %%
df['Experience_Years'].unique()
# Out:
# array([14,  7,  2,  1,  0,  4,  9,  5,  6,  8,  3, 10, 11, 12, 13, 15])

# %%
sns.countplot(x = 'Experience_Years', data = df)
plt.show()

# %%
df['Experience_Years'].value_counts()
# Out:
# Experience_Years
# 3     200522
# 2     199924
# 4     199866
# 1     199162
# 0     198775
# 6     160410
# 9     160223
# 8     160212
# 5     160112
# 7     159005
# 10     41209
# 13     40149
# 11     40146
# 14     40005
# 12     39709
# 15       571
# Name: count, dtype: int64

# %%
# Consider the columns having data type 'Object' only
df.select_dtypes( include = 'object')
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  \
# 0                    Software Engineer
# 1                       SEO Specialist
# 2                           HR Manager
# 3                    Software Engineer
# 4                Logistics Coordinator
# ...                                ...
# 1999995          Logistics Coordinator
# 1999996              Software Engineer
# 1999997   Business Development Manager
# 1999998              Software Engineer
# 1999999  Talent Acquisition Specialist
#
#                                         Location    Status Work_Mode
# 0                             Isaacland, Denmark  Resigned   On-site
# 1                        Anthonyside, Costa Rica    Active   On-site
# 2               Port Christinaport, Saudi Arabia    Active   On-site
# 3        Port Shelbychester, Antigua and Barbuda    Active   On-site
# 4           Lake Kimberly, Palestinian Territory    Active   On-site
# ...                                          ...       ...       ...
# 1999995                         Casefurt, Serbia    Active    Remote
# 1999996                        Dannyport, Kuwait    Active   On-site
# 1999997                      Craighaven, Nigeria    Active    Remote
# 1999998                  Jonathanmouth, Djibouti   Retired   On-site
# 1999999                    Morganchester, Canada    Active    Remote
#
# [2000000 rows x 7 columns]

# %%
df.select_dtypes( include = 'number')
# Out:
#          Performance_Rating  Experience_Years  Salary_INR
# 0                         5                14     1585363
# 1                         2                 7      847686
# 2                         1                 2     1430084
# 3                         1                 1      990689
# 4                         5                 0      535082
# ...                     ...               ...         ...
# 1999995                   3                14      657648
# 1999996                   3                 4     1030109
# 1999997                   5                 1     1313085
# 1999998                   4                 2     1479727
# 1999999                   1                 4      993718
#
# [2000000 rows x 3 columns]

# %% [markdown]
# #### Q.1. What is the distribution of Employee Status(Active, Resigned, Retired, Terminated)?

# %%
status = df['Status'].value_counts()
status
# Out:
# Status
# Active        1401558
# Resigned       398660
# Retired         99912
# Terminated      99870
# Name: count, dtype: int64

# %%
type(status)
# Out:
# pandas.core.series.Series

# %%
status.plot(kind = 'pie', colors = 'crmb', autopct= '%1.1f%%', explode=(0.03,0.03,0.03,0.03))
plt.show()

# %% [markdown]
# #### Q.2. What is the distribution of work modes (On-site, Remote) ?

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
work = df['Work_Mode'].value_counts()
work
# Out:
# Work_Mode
# On-site    1199109
# Remote      800891
# Name: count, dtype: int64

# %%
work.plot(kind = 'pie', colors = 'gy', autopct = '%1.1f%%', shadow = True)
plt.show()

# %% [markdown]
# #### Q.3. How many employees are there in each department?

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            601042
# Sales         400031
# Operations    300095
# Marketing     240081
# Finance       199873
# HR            159119
# R&D            99759
# Name: count, dtype: int64

# %%
sns.countplot( x = 'Department', data = df)
plt.show()

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Software Engineer                300358
# Sales Executive                  199982
# Operations Executive             150058
# Data Analyst                     120375
# Marketing Executive              120154
# Account Manager                  119929
# Accountant                       100307
# DevOps Engineer                   90197
# Logistics Coordinator             90188
# HR Executive                      79348
# SEO Specialist                    71692
# Business Development Manager      60233
# IT Manager                        60224
# Financial Analyst                 59815
# Research Scientist                50017
# Talent Acquisition Specialist     47994
# Supply Chain Manager              44935
# Content Strategist                36154
# CTO                               29888
# Product Developer                 29872
# Finance Manager                   29799
# HR Manager                        23841
# Sales Director                    19887
# Operations Director               14914
# Lab Technician                    14829
# Brand Manager                     12081
# CFO                                9952
# HR Director                        7936
# Innovation Manager                 5041
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot( x = 'Job_Title', data = df, palette='viridis', hue='Job_Title')
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# #### Q.4. What is the average salary by Department?

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# 1                 7    Active   On-site      847686
# 2                 2    Active   On-site     1430084
# 3                 1    Active   On-site      990689
# 4                 0    Active   On-site      535082

# %%
dept = df.groupby('Department')['Salary_INR'].mean()/1000
dept
# Out:
# Department
# Finance        940.411743
# HR             743.853561
# IT            1129.858151
# Marketing      769.936152
# Operations     754.626253
# R&D            800.377157
# Sales          792.957860
# Name: Salary_INR, dtype: float64

# %%
type(dept)
# Out:
# pandas.core.series.Series

# %%
dept.plot(x=dept.index, y=dept.values, kind='bar', color='c', legend=True, width=0.4)
plt.title("Average Salary in Departments")
plt.show()

# %% [markdown]
# #### Q.5. Which job title has the highest average salary?

# %%
salary = df.groupby('Job_Title')['Salary_INR'].mean()/1000
salary
# Out:
# Job_Title
# Account Manager                   799.373734
# Accountant                        650.076482
# Brand Manager                     803.127787
# Business Development Manager     1252.016231
# CFO                               795.015873
# CTO                               801.402754
# Content Strategist                800.760030
# Data Analyst                      800.996380
# DevOps Engineer                   799.949184
# Finance Manager                  1743.241525
# Financial Analyst                1051.522903
# HR Director                       800.694437
# HR Executive                      550.548859
# HR Manager                       1252.401915
# IT Manager                       2098.155777
# Innovation Manager                801.870103
# Lab Technician                    800.181468
# Logistics Coordinator             649.631726
# Marketing Executive               798.780404
# Operations Director               798.298093
# Operations Executive              800.350915
# Product Developer                 798.652261
# Research Scientist                801.314879
# SEO Specialist                    700.456337
# Sales Director                    799.069374
# Sales Executive                   650.237755
# Software Engineer                1199.260843
# Supply Chain Manager              798.168555
# Talent Acquisition Specialist     801.422237
# Name: Salary_INR, dtype: float64

# %%
plt.figure(figsize=(10,6))
salary.plot(x = salary.index, y = salary.values, kind = 'bar', color = 'y')
plt.grid(True)
plt.title("Average Salary wrt Job Title")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# #### Q.6. What is the average salary in different Department based in Job Title?

# %%
df.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dept_job = df.groupby(['Department', 'Job_Title'])['Salary_INR'].mean()/1000
dept_job
# Out:
# Department  Job_Title
# Finance     Accountant                        650.076482
#             CFO                               795.015873
#             Finance Manager                  1743.241525
#             Financial Analyst                1051.522903
# HR          HR Director                       800.694437
#             HR Executive                      550.548859
#             HR Manager                       1252.401915
#             Talent Acquisition Specialist     801.422237
# IT          CTO                               801.402754
#             Data Analyst                      800.996380
#             DevOps Engineer                   799.949184
#             IT Manager                       2098.155777
#             Software Engineer                1199.260843
# Marketing   Brand Manager                     803.127787
#             Content Strategist                800.760030
#             Marketing Executive               798.780404
#             SEO Specialist                    700.456337
# Operations  Logistics Coordinator             649.631726
#             Operations Director               798.298093
#             Operations Executive              800.350915
#             Supply Chain Manager              798.168555
# R&D         Innovation Manager                801.870103
#             Lab Technician                    800.181468
#             Product Developer                 798.652261
#             Research Scientist                801.314879
# Sales       Account Manager                   799.373734
#             Business Development Manager     1252.016231
#             Sales Director                    799.069374
#             Sales Executive                   650.237755
# Name: Salary_INR, dtype: float64

# %%
import random
num_bars = len(dept_job)
random_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in range(num_bars)]

dept_job.plot(kind = 'barh', figsize = (10,5), color = random_colors)
plt.title('Average Salary in Different Department')
plt.xlabel("Salary")

plt.savefig('new_chart.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Q.7. How many employees Resigned & Terminated in each department ?

# %%
df.Status.unique()
# Out:
# array(['Resigned', 'Active', 'Terminated', 'Retired'], dtype=object)

# %%
df_Resigned = df[df['Status'] == 'Resigned']
df_Resigned
# Out:
#         Employee_ID         Full_Name  Department              Job_Title  \
# 0        EMP0000001     Joshua Nguyen          IT      Software Engineer
# 8        EMP0000009    Cathy Thompson     Finance      Financial Analyst
# 11       EMP0000012        Kevin Lowe       Sales        Account Manager
# 16       EMP0000017     Robert Martin  Operations  Logistics Coordinator
# 19       EMP0000020    Donald Hoffman   Marketing     Content Strategist
# ...             ...               ...         ...                    ...
# 1999976  EMP1999977     Angela Curtis  Operations   Operations Executive
# 1999983  EMP1999984      Joshua Ponce       Sales        Account Manager
# 1999985  EMP1999986  Aaron Montgomery   Marketing    Marketing Executive
# 1999986  EMP1999987      Mason Parker  Operations   Operations Executive
# 1999989  EMP1999990      Adrian Lopez       Sales        Sales Executive
#
#          Hire_Date                      Location  Performance_Rating  \
# 0       2011-08-10            Isaacland, Denmark                   5
# 8       2018-05-29       South Catherine, Belize                   4
# 11      2024-07-02              East Kent, Qatar                   3
# 16      2025-05-13       Laurahaven, Afghanistan                   3
# 19      2022-04-01      South James, New Zealand                   3
# ...            ...                           ...                 ...
# 1999976 2021-08-07    East Jeremiahburgh, Rwanda                   4
# 1999983 2020-05-08       North Tracey, Venezuela                   4
# 1999985 2017-06-03           Maddenmouth, Belize                   5
# 1999986 2018-02-27            Joseside, Cameroon                   2
# 1999989 2017-07-25  North Elizabethfort, Morocco                   3
#
#          Experience_Years    Status Work_Mode  Salary_INR
# 0                      14  Resigned   On-site     1585363
# 8                       7  Resigned    Remote     1138452
# 11                      1  Resigned   On-site     1111759
# 16                      0  Resigned   On-site      859025
# 19                      3  Resigned   On-site      965154
# ...                   ...       ...       ...         ...
# 1999976                 4  Resigned   On-site      602517
# 1999983                 5  Resigned   On-site      547090
# 1999985                 8  Resigned    Remote      693363
# 1999986                 7  Resigned   On-site      581507
# 1999989                 8  Resigned    Remote      671088
#
# [398660 rows x 11 columns]

# %%
R_emp = df_Resigned.groupby('Department')['Status'].count()
R_emp
# Out:
# Department
# Finance        40238
# HR             31736
# IT            119852
# Marketing      47793
# Operations     59397
# R&D            19919
# Sales          79725
# Name: Status, dtype: int64

# %%
R_emp.plot(x = R_emp.index, y = R_emp.values , kind = 'bar', color = 'k', legend = True, label = 'Resigned')
plt.title("No. of the Resigned employees")
plt.ylabel("count")
plt.show()

# %%
df_Terminated = df[df['Status'] == 'Terminated']
df_Terminated
# Out:
#         Employee_ID              Full_Name Department            Job_Title  \
# 20       EMP0000021  Mr. Billy Rodgers DDS  Marketing  Marketing Executive
# 33       EMP0000034          Steve Carlson         IT    Software Engineer
# 56       EMP0000057        Claire Martinez         IT      DevOps Engineer
# 100      EMP0000101         Johnny Shepard    Finance           Accountant
# 121      EMP0000122          Vanessa Brown         IT         Data Analyst
# ...             ...                    ...        ...                  ...
# 1999912  EMP1999913     Stefanie Valentine  Marketing   Content Strategist
# 1999936  EMP1999937            Lisa Gordon    Finance    Financial Analyst
# 1999947  EMP1999948           John Johnson      Sales      Sales Executive
# 1999981  EMP1999982         Mindy Campbell      Sales      Account Manager
# 1999993  EMP1999994          Ashley Fuller         IT      DevOps Engineer
#
#          Hire_Date                           Location  Performance_Rating  \
# 20      2017-10-12        West Bryanton, Saint Martin                   3
# 33      2020-04-25                Grahamfurt, Jamaica                   5
# 56      2020-01-17  Garciaton, Libyan Arab Jamahiriya                   5
# 100     2023-02-02            North Briannatown, Cuba                   4
# 121     2017-08-14        South Teresa, Liechtenstein                   3
# ...            ...                                ...                 ...
# 1999912 2016-05-04              New Aaronton, Andorra                   4
# 1999936 2025-02-25                 Baxtermouth, Qatar                   5
# 1999947 2019-11-13                 Maryborough, Nepal                   1
# 1999981 2018-07-16             Sharonchester, Belgium                   2
# 1999993 2018-06-09                Dylanhaven, Bermuda                   3
#
#          Experience_Years      Status Work_Mode  Salary_INR
# 20                      7  Terminated   On-site      796532
# 33                      5  Terminated   On-site     1039192
# 56                      5  Terminated    Remote      838341
# 100                     2  Terminated   On-site      892140
# 121                     8  Terminated   On-site      495474
# ...                   ...         ...       ...         ...
# 1999912                 9  Terminated    Remote      949807
# 1999936                 0  Terminated   On-site     1288980
# 1999947                 5  Terminated    Remote      574391
# 1999981                 7  Terminated   On-site      705933
# 1999993                 7  Terminated    Remote      892372
#
# [99870 rows x 11 columns]

# %%
T_emp = df_Terminated.groupby('Department')['Status'].count()
T_emp
# Out:
# Department
# Finance        9988
# HR             7861
# IT            29881
# Marketing     12044
# Operations    14884
# R&D            4998
# Sales         20214
# Name: Status, dtype: int64

# %%
plt.figure(figsize=(8,4))
T_emp.plot(x = T_emp.index, y = T_emp.values, kind = 'bar',color = 'orange', legend = True, label = 'Terminated')
plt.title("No. of the Terminated employees")
plt.ylabel("count")
plt.show()

# %%
R_emp.plot(x = R_emp.index, y = R_emp.values , kind = 'bar', color = 'k', legend = True, label = 'Resigned')
T_emp.plot(x = T_emp.index, y = T_emp.values, kind = 'bar',color = 'orange', legend = True, label = 'Terminated')
plt.ylabel("Cunt of Employees")
plt.legend(title= "Employee Status")
plt.show()

# %% [markdown]
# #### Q.8. How does salary vary with years of experience ?

# %%
df['Experience_Years'].nunique()
# Out:
# 16

# %%
df.groupby('Experience_Years')['Salary_INR'].mean()
# Out:
# Experience_Years
# 0     896737.454775
# 1     895903.759824
# 2     896755.652313
# 3     896861.245240
# 4     897944.573965
# 5     896484.084828
# 6     896012.632467
# 7     895722.673960
# 8     897148.361090
# 9     898482.940577
# 10    895662.027882
# 11    901452.750112
# 12    896432.933416
# 13    898790.197041
# 14    895610.790251
# 15    895647.401051
# Name: Salary_INR, dtype: float64

# %% [markdown]
# #### Q.9. What is the average performance rating by department?

# %%
df.head(2)
# Out:
#    Unnamed: 0 Employee_ID       Full_Name Department          Job_Title  \
# 0           0  EMP0000001   Joshua Nguyen         IT  Software Engineer
# 1           1  EMP0000002  Julie Williams  Marketing     SEO Specialist
#
#     Hire_Date                 Location  Performance_Rating  Experience_Years  \
# 0  2011-08-10       Isaacland, Denmark                   5                14
# 1  2018-03-02  Anthonyside, Costa Rica                   2                 7
#
#      Status Work_Mode  Salary_INR
# 0  Resigned   On-site     1585363
# 1    Active   On-site      847686

# %%
PR = df.groupby('Department')['Performance_Rating'].mean()
PR
# Out:
# Department
# Finance       2.996818
# HR            2.995670
# IT            2.998216
# Marketing     3.004736
# Operations    2.996081
# R&D           3.001885
# Sales         3.006362
# Name: Performance_Rating, dtype: float64

# %%
plt.figure(figsize=(8,4))
PR.plot(x=PR.index, y= PR.values, kind='bar', color = 'lightgreen')
plt.title("Average Performance Rating Department Wise")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# #### Q.10. Which Country have the highest concentration of employees?

# %%
df.head()
# Out:
#    Unnamed: 0 Employee_ID        Full_Name  Department              Job_Title  \
# 0           0  EMP0000001    Joshua Nguyen          IT      Software Engineer
# 1           1  EMP0000002   Julie Williams   Marketing         SEO Specialist
# 2           2  EMP0000003  Alyssa Martinez          HR             HR Manager
# 3           3  EMP0000004  Nicholas Valdez          IT      Software Engineer
# 4           4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator
#
#     Hire_Date                                 Location  Performance_Rating  \
# 0  2011-08-10                       Isaacland, Denmark                   5
# 1  2018-03-02                  Anthonyside, Costa Rica                   2
# 2  2023-03-20         Port Christinaport, Saudi Arabia                   1
# 3  2023-10-12  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024-12-09     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# 1                 7    Active   On-site      847686
# 2                 2    Active   On-site     1430084
# 3                 1    Active   On-site      990689
# 4                 0    Active   On-site      535082

# %%
df['Country'] = df['Location'].apply( lambda x : str(x.split(',')[1]))
df
# Out:
#          Unnamed: 0 Employee_ID         Full_Name  Department  \
# 0                 0  EMP0000001     Joshua Nguyen          IT
# 1                 1  EMP0000002    Julie Williams   Marketing
# 2                 2  EMP0000003   Alyssa Martinez          HR
# 3                 3  EMP0000004   Nicholas Valdez          IT
# 4                 4  EMP0000005    Joel Hendricks  Operations
# ...             ...         ...               ...         ...
# 1999995     1999995  EMP1999996      Cody Russell  Operations
# 1999996     1999996  EMP1999997      Tracey Smith          IT
# 1999997     1999997  EMP1999998         Tracy Lee       Sales
# 1999998     1999998  EMP1999999  Michael Roberson          IT
# 1999999     1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title   Hire_Date  \
# 0                    Software Engineer  2011-08-10
# 1                       SEO Specialist  2018-03-02
# 2                           HR Manager  2023-03-20
# 3                    Software Engineer  2023-10-12
# 4                Logistics Coordinator  2024-12-09
# ...                                ...         ...
# 1999995          Logistics Coordinator  2010-08-31
# 1999996              Software Engineer  2021-05-07
# 1999997   Business Development Manager  2024-05-29
# 1999998              Software Engineer  2023-02-14
# 1999999  Talent Acquisition Specialist  2020-11-11
#
#                                         Location  Performance_Rating  \
# 0                             Isaacland, Denmark                   5
# 1                        Anthonyside, Costa Rica                   2
# 2               Port Christinaport, Saudi Arabia                   1
# 3        Port Shelbychester, Antigua and Barbuda                   1
# 4           Lake Kimberly, Palestinian Territory                   5
# ...                                          ...                 ...
# 1999995                         Casefurt, Serbia                   3
# 1999996                        Dannyport, Kuwait                   3
# 1999997                      Craighaven, Nigeria                   5
# 1999998                  Jonathanmouth, Djibouti                   4
# 1999999                    Morganchester, Canada                   1
#
#          Experience_Years    Status Work_Mode  Salary_INR  \
# 0                      14  Resigned   On-site     1585363
# 1                       7    Active   On-site      847686
# 2                       2    Active   On-site     1430084
# 3                       1    Active   On-site      990689
# 4                       0    Active   On-site      535082
# ...                   ...       ...       ...         ...
# 1999995                14    Active    Remote      657648
# 1999996                 4    Active   On-site     1030109
# 1999997                 1    Active    Remote     1313085
# 1999998                 2   Retired   On-site     1479727
# 1999999                 4    Active    Remote      993718
#
#                         Country
# 0                       Denmark
# 1                    Costa Rica
# 2                  Saudi Arabia
# 3           Antigua and Barbuda
# 4         Palestinian Territory
# ...                         ...
# 1999995                  Serbia
# 1999996                  Kuwait
# 1999997                 Nigeria
# 1999998                Djibouti
# 1999999                  Canada
#
# [2000000 rows x 13 columns]

# %%
df.Country.nunique()
# Out:
# 243

# %%
df.Country.value_counts()
# Out:
# Country
# Congo                     16286
# Korea                     16285
# Sri Lanka                  8409
# Switzerland                8391
# British Virgin Islands     8373
#                           ...
# Indonesia                  7983
# Kazakhstan                 7973
# Montenegro                 7972
# Bhutan                     7971
# Palestinian Territory      7895
# Name: count, Length: 243, dtype: int64

# %% [markdown]
# #### Q.11. Is there a correlation between performance rating and salary?

# %%
df.head(2)
# Out:
#    Unnamed: 0 Employee_ID       Full_Name Department          Job_Title  \
# 0           0  EMP0000001   Joshua Nguyen         IT  Software Engineer
# 1           1  EMP0000002  Julie Williams  Marketing     SEO Specialist
#
#     Hire_Date                 Location  Performance_Rating  Experience_Years  \
# 0  2011-08-10       Isaacland, Denmark                   5                14
# 1  2018-03-02  Anthonyside, Costa Rica                   2                 7
#
#      Status Work_Mode  Salary_INR      Country
# 0  Resigned   On-site     1585363      Denmark
# 1    Active   On-site      847686   Costa Rica

# %%
df['Performance_Rating'].corr(df['Salary_INR'])
# Out:
# np.float64(-0.00020919799940916222)

# %%
df[['Performance_Rating','Salary_INR']].corr()
# Out:
#                     Performance_Rating  Salary_INR
# Performance_Rating            1.000000   -0.000209
# Salary_INR                   -0.000209    1.000000

# %%
sns.heatmap(df.corr(numeric_only = True))
plt.show()

# %% [markdown]
# #### Q.12. How has the number of hire changed over time(per year) ?

# %%
df.head(2)
# Out:
#    Unnamed: 0 Employee_ID       Full_Name Department          Job_Title  \
# 0           0  EMP0000001   Joshua Nguyen         IT  Software Engineer
# 1           1  EMP0000002  Julie Williams  Marketing     SEO Specialist
#
#     Hire_Date                 Location  Performance_Rating  Experience_Years  \
# 0  2011-08-10       Isaacland, Denmark                   5                14
# 1  2018-03-02  Anthonyside, Costa Rica                   2                 7
#
#      Status Work_Mode  Salary_INR      Country
# 0  Resigned   On-site     1585363      Denmark
# 1    Active   On-site      847686   Costa Rica

# %%
df['Hire_Date'] = pd.to_datetime(df['Hire_Date'])

# %%
df.Hire_Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.insert(5, 'Year', df['Hire_Date'].dt.year)
df
# Out:
#          Unnamed: 0 Employee_ID         Full_Name  Department  \
# 0                 0  EMP0000001     Joshua Nguyen          IT
# 1                 1  EMP0000002    Julie Williams   Marketing
# 2                 2  EMP0000003   Alyssa Martinez          HR
# 3                 3  EMP0000004   Nicholas Valdez          IT
# 4                 4  EMP0000005    Joel Hendricks  Operations
# ...             ...         ...               ...         ...
# 1999995     1999995  EMP1999996      Cody Russell  Operations
# 1999996     1999996  EMP1999997      Tracey Smith          IT
# 1999997     1999997  EMP1999998         Tracy Lee       Sales
# 1999998     1999998  EMP1999999  Michael Roberson          IT
# 1999999     1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  Year  Hire_Date  \
# 0                    Software Engineer  2011 2011-08-10
# 1                       SEO Specialist  2018 2018-03-02
# 2                           HR Manager  2023 2023-03-20
# 3                    Software Engineer  2023 2023-10-12
# 4                Logistics Coordinator  2024 2024-12-09
# ...                                ...   ...        ...
# 1999995          Logistics Coordinator  2010 2010-08-31
# 1999996              Software Engineer  2021 2021-05-07
# 1999997   Business Development Manager  2024 2024-05-29
# 1999998              Software Engineer  2023 2023-02-14
# 1999999  Talent Acquisition Specialist  2020 2020-11-11
#
#                                         Location  Performance_Rating  \
# 0                             Isaacland, Denmark                   5
# 1                        Anthonyside, Costa Rica                   2
# 2               Port Christinaport, Saudi Arabia                   1
# 3        Port Shelbychester, Antigua and Barbuda                   1
# 4           Lake Kimberly, Palestinian Territory                   5
# ...                                          ...                 ...
# 1999995                         Casefurt, Serbia                   3
# 1999996                        Dannyport, Kuwait                   3
# 1999997                      Craighaven, Nigeria                   5
# 1999998                  Jonathanmouth, Djibouti                   4
# 1999999                    Morganchester, Canada                   1
#
#          Experience_Years    Status Work_Mode  Salary_INR  \
# 0                      14  Resigned   On-site     1585363
# 1                       7    Active   On-site      847686
# 2                       2    Active   On-site     1430084
# 3                       1    Active   On-site      990689
# 4                       0    Active   On-site      535082
# ...                   ...       ...       ...         ...
# 1999995                14    Active    Remote      657648
# 1999996                 4    Active   On-site     1030109
# 1999997                 1    Active    Remote     1313085
# 1999998                 2   Retired   On-site     1479727
# 1999999                 4    Active    Remote      993718
#
#                         Country
# 0                       Denmark
# 1                    Costa Rica
# 2                  Saudi Arabia
# 3           Antigua and Barbuda
# 4         Palestinian Territory
# ...                         ...
# 1999995                  Serbia
# 1999996                  Kuwait
# 1999997                 Nigeria
# 1999998                Djibouti
# 1999999                  Canada
#
# [2000000 rows x 14 columns]

# %%
df.Year.unique()
# Out:
# array([2011, 2018, 2023, 2024, 2021, 2016, 2020, 2015, 2025, 2022, 2017,
#        2019, 2014, 2013, 2012, 2010], dtype=int32)

# %%
df.Year.nunique()
# Out:
# 16

# %%
hire = df.groupby('Year')['Employee_ID'].count()
hire
# Out:
# Year
# 2010     15520
# 2011     40089
# 2012     39765
# 2013     39988
# 2014     40202
# 2015     85984
# 2016    160249
# 2017    160363
# 2018    159658
# 2019    160202
# 2020    175460
# 2021    199366
# 2022    201373
# 2023    198982
# 2024    200001
# 2025    122798
# Name: Employee_ID, dtype: int64

# %%
plt.figure(figsize=(10,4))
hire.plot(x=hire.index, y= hire.values, kind='bar', color = 'violet')
plt.grid(True, color = 'w')
plt.title("No. of Employees Hired in any year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### Q.13. Compare salaries of Remote vs On-Site employees is there a significant difference ?

# %%
df.head(2)
# Out:
#    Unnamed: 0 Employee_ID       Full_Name Department          Job_Title  Year  \
# 0           0  EMP0000001   Joshua Nguyen         IT  Software Engineer  2011
# 1           1  EMP0000002  Julie Williams  Marketing     SEO Specialist  2018
#
#    Hire_Date                 Location  Performance_Rating  Experience_Years  \
# 0 2011-08-10       Isaacland, Denmark                   5                14
# 1 2018-03-02  Anthonyside, Costa Rica                   2                 7
#
#      Status Work_Mode  Salary_INR      Country
# 0  Resigned   On-site     1585363      Denmark
# 1    Active   On-site      847686   Costa Rica

# %%
df.groupby('Work_Mode')['Salary_INR'].mean()
# Out:
# Work_Mode
# On-site    896835.945792
# Remote     896965.326373
# Name: Salary_INR, dtype: float64

# %% [markdown]
# #### Q.14. Find the Top 10 employees with the highest salary in each department?

# %%
top_10 = df.groupby('Department').apply(lambda x:x.nlargest(10, "Salary_INR"), include_groups=False)

# %%
top_10.head(40)
# Out:
#                     Unnamed: 0 Employee_ID           Full_Name  \
# Department
# Finance    888712       888712  EMP0888713   Christopher Sloan
#            695808       695808  EMP0695809        Todd Rodgers
#            459273       459273  EMP0459274        Angela Payne
#            750893       750893  EMP0750894           Nina Lara
#            780290       780290  EMP0780291   Brittany Thompson
#            1316795     1316795  EMP1316796        Larry Wilson
#            737507       737507  EMP0737508    Alexis Schroeder
#            781352       781352  EMP0781353         Sarah Jones
#            803785       803785  EMP0803786       Jose Anderson
#            905337       905337  EMP0905338  Jennifer Dominguez
# HR         223845       223845  EMP0223846         Ethan Jones
#            1068270     1068270  EMP1068271         Austin Hall
#            1541972     1541972  EMP1541973       Daniel Wilson
#            1861401     1861401  EMP1861402      Amanda Everett
#            553718       553718  EMP0553719     Michelle Snyder
#            674999       674999  EMP0675000     Andre Velasquez
#            230232       230232  EMP0230233        Carrie Davis
#            1489953     1489953  EMP1489954     Gregory Pearson
#            1863268     1863268  EMP1863269    Dr. Shawn Gibson
#            1708267     1708267  EMP1708268          Anna Munoz
# IT         1697605     1697605  EMP1697606       Kathryn Owens
#            1284141     1284141  EMP1284142       Robert Bowman
#            1912378     1912378  EMP1912379   Christina Delgado
#            1904593     1904593  EMP1904594        Donald Cohen
#            645146       645146  EMP0645147   Brandon Rodriguez
#            766571       766571  EMP0766572  Dr. David Mitchell
#            1257897     1257897  EMP1257898   Cassandra Morales
#            1734354     1734354  EMP1734355        Debra Rivera
#            369339       369339  EMP0369340        Douglas Mann
#            1645827     1645827  EMP1645828   Jennifer Reynolds
# Marketing  1268998     1268998  EMP1268999         Shannon Fox
#            1015129     1015129  EMP1015130         Laura Allen
#            1214216     1214216  EMP1214217      Rebecca Davies
#            373011       373011  EMP0373012         Dylan Davis
#            158254       158254  EMP0158255          Jamie Carr
#            1848468     1848468  EMP1848469         Lisa Warren
#            814806       814806  EMP0814807        Daniel Cline
#            1117910     1117910  EMP1117911         Tyler Fritz
#            1062763     1062763  EMP1062764         John Howard
#            1468982     1468982  EMP1468983      Russell Parker
#
#                               Job_Title  Year  Hire_Date  \
# Department
# Finance    888712       Finance Manager  2011 2011-07-19
#            695808       Finance Manager  2019 2019-12-27
#            459273       Finance Manager  2021 2021-08-12
#            750893       Finance Manager  2021 2021-10-19
#            780290       Finance Manager  2021 2021-07-23
#            1316795      Finance Manager  2015 2015-01-30
#            737507       Finance Manager  2024 2024-10-28
#            781352       Finance Manager  2018 2018-04-02
#            803785       Finance Manager  2020 2020-11-17
#            905337       Finance Manager  2018 2018-03-22
#            1219675   On-site     1199977                  Kazakhstan
#            1462996    Remote     1199977                 Netherlands
#            602560    On-site     1199973                        Cuba
#            578541    On-site     1199971                       Egypt
#            1639976   On-site     1199970        Netherlands Antilles
#            1511593   On-site     1199963                      Belize
#            1729961   On-site     1199961                      Rwanda
#            1178609    Remote     1199956   Bouvet Island (Bouvetoya)
# R&D        1601509   On-site     1199995                      Panama
#            1870413   On-site     1199950                      Greece
#            1992769    Remote     1199943    Northern Mariana Islands
#            1143137    Remote     1199936                    Guernsey
#            1608754   On-site     1199936                      France
#            1452254    Remote     1199934                      France
#            1882072    Remote     1199921                  Tajikistan
#            943039     Remote     1199919            Christmas Island
#            137313    On-site     1199917                  Luxembourg
#            196679     Remote     1199911                     Belgium
# Sales      1729875    Remote     1799983                       Samoa
#            3493      On-site     1799975                     Uruguay
#            161163    On-site     1799975                     Albania
#            50430     On-site     1799923                    Dominica
#            339734    On-site     1799923                     Reunion
#            86194      Remote     1799913    Central African Republic
#            1116580   On-site     1799903                     Uruguay
#            1760918   On-site     1799881                    Dominica
#            1878661   On-site     1799877                      Serbia
#            1333220    Remote     1799858                    Slovenia

# %% [markdown]
# #### Q.15. Identify department with the highest attrition rate (Resigned %)

# %%
df.head(2)
# Out:
#    Unnamed: 0 Employee_ID       Full_Name Department          Job_Title  Year  \
# 0           0  EMP0000001   Joshua Nguyen         IT  Software Engineer  2011
# 1           1  EMP0000002  Julie Williams  Marketing     SEO Specialist  2018
#
#    Hire_Date                 Location  Performance_Rating  Experience_Years  \
# 0 2011-08-10       Isaacland, Denmark                   5                14
# 1 2018-03-02  Anthonyside, Costa Rica                   2                 7
#
#      Status Work_Mode  Salary_INR      Country
# 0  Resigned   On-site     1585363      Denmark
# 1    Active   On-site      847686   Costa Rica

# %%
dept_counts = df.groupby('Department')['Status'].agg(total_emp = 'count', resigned = lambda x: (x == 'Resigned').sum())
dept_counts
# Out:
#             total_emp  resigned
# Department
# Finance        199873     40238
# HR             159119     31736
# IT             601042    119852
# Marketing      240081     47793
# Operations     300095     59397
# R&D             99759     19919
# Sales          400031     79725

# %%
type(dept_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
# Calculate attrition rate

dept_counts['attrition_rate_%'] = (dept_counts['resigned'] / dept_counts['total_emp'])*100
dept_counts
# Out:
#             total_emp  resigned  attrition_rate_%
# Department
# Finance        199873     40238         20.131784
# HR             159119     31736         19.944821
# IT             601042    119852         19.940703
# Marketing      240081     47793         19.907031
# Operations     300095     59397         19.792732
# R&D             99759     19919         19.967121
# Sales          400031     79725         19.929705

# %%
# Sort by attrition rate (highest first)

dept_counts.sort_values("attrition_rate_%", ascending = False)
# Out:
#             total_emp  resigned  attrition_rate_%
# Department
# Finance        199873     40238         20.131784
# R&D             99759     19919         19.967121
# HR             159119     31736         19.944821
# IT             601042    119852         19.940703
# Sales          400031     79725         19.929705
# Marketing      240081     47793         19.907031
# Operations     300095     59397         19.792732
